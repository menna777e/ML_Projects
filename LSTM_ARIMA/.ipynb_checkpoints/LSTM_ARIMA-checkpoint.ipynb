# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("AXISBANK.NS.csv")
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-02-08  726.000000  747.799988  726.000000  736.150024  736.150024
# 1  2021-02-09  735.750000  750.000000  726.200012  742.500000  742.500000
# 2  2021-02-10  741.549988  746.400024  726.099976  734.799988  734.799988
# 3  2021-02-11  731.000000  744.150024  731.000000  740.099976  740.099976
# 4  2021-02-12  735.500000  754.700012  734.549988  750.400024  750.400024
#
#      Volume
# 0  15662890
# 1  22307807
# 2  15140744
# 3  11897710
# 4  15668442

# %%
df1=df.reset_index()['Close']
df1
# Out:
# 0      736.150024
# 1      742.500000
# 2      734.799988
# 3      740.099976
# 4      750.400024
#           ...
# 244    804.099976
# 245    799.549988
# 246    798.549988
# 247    789.599976
# 248    798.549988
# Name: Close, Length: 249, dtype: float64

# %%
plt.plot(df1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
##splitting dataset into train and test split
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(train_data, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
training_size,test_size
# Out:
# (161, 88)

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----10 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 10
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
y_train
# Out:
# array([0.40023884, 0.38353239, 0.54319832, 0.6446303 , 0.42577571,
#        0.44367547, 0.45656336, 0.56491664, 0.48305495, 0.45417673,
#        0.5140812 , 0.52434385, 0.59737482, 0.54892601, 0.51933197,
#        0.48758961, 0.44057302, 0.39689749, 0.43269701, 0.38472571,
#        0.45322201, 0.33794772, 0.28162291, 0.29880685, 0.28520286,
#        0.2952269 , 0.36945119, 0.23699295, 0.20190954, 0.25131276,
#        0.21957041, 0.15560876, 0.        , 0.12124116, 0.15871122,
#        0.16038203, 0.05990476, 0.07708842, 0.1102627 , 0.17064439,
#        0.30954671, 0.30525065, 0.34630095, 0.40000023, 0.37852052,
#        0.32052517, 0.30906921, 0.38949898, 0.38257768, 0.38735095,
#        0.38019105, 0.3424821 , 0.26587118, 0.23579964, 0.35155143,
#        0.36300739, 0.38758956, 0.33556109, 0.45489283, 0.50381884,
#        0.45799528, 0.47494033, 0.5477327 , 0.49761337, 0.54940351,
#        0.52291192, 0.48400966, 0.54916491, 0.50811462, 0.55131265,
#        0.52863962, 0.48281634, 0.51861587, 0.49093096, 0.48042971,
#        0.55035822, 0.54510746, 0.49164678, 0.48066832, 0.49618144,
#        0.49522673, 0.46181384, 0.49427231, 0.60023866, 0.60525083,
#        0.5553701 , 0.53794755, 0.52911712, 0.54916491, 0.59546539,
#        0.58591885, 0.60763746, 0.56706467, 0.53341289, 0.56324582,
#        0.64510751, 0.64176617, 0.66133674, 0.64701694, 0.57088323,
#        0.52577577, 0.53054904, 0.57183794, 0.57613371, 0.45871139,
#        0.41670667, 0.38973758, 0.3498809 , 0.40835345, 0.49164678,
#        0.56420053, 0.54272082, 0.50238663, 0.57231515, 0.60119337,
#        0.59761342, 0.58114558, 0.59331765, 0.6033414 , 0.57828174,
#        0.56706467, 0.49952279, 0.4797136 , 0.52863962, 0.49379481,
#        0.52863962, 0.55751813, 0.70859194, 0.72028651, 0.77947517,
#        0.79761354, 0.77517911, 0.78854421, 0.72673031, 0.75942738,
#        0.73770906, 0.72911695, 0.75799546, 0.74367565, 0.79713604,
#        0.81980907, 0.76491647, 0.76252983, 0.72911695, 0.84272099,
#        0.77541772, 0.77016724, 0.7331744 , 0.6995229 , 0.62505972])

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (150, 10)
# (150,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
#x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Out:
# (150, 10)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM 
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
# LSTM MODEL
model = Sequential()

# IF you are running with a GPU, try out the CuDNNLSTM layer type instead (don't pass an activation, tanh is required)
model.add(LSTM(100, input_shape=(X_train.shape[1], 1), activation='relu', return_sequences=True))

model.add(LSTM(100, activation='relu', return_sequences=False))

model.add(Dense(50))

model.add(Dense(1))

model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (None, 10, 50)            10400
#
#  lstm_12 (LSTM)              (None, 10, 50)            20200
#
#  dense_10 (Dense)            (None, 10, 50)            2550
#
#  dense_11 (Dense)            (None, 10, 1)             51
#
# =================================================================
# Total params: 33,201
# Trainable params: 33,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 165ms/step - loss: 0.2716 - val_loss: 0.1735
# Epoch 2/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1824 - val_loss: 0.1045
# Epoch 3/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0996 - val_loss: 0.0429
# Epoch 4/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0295 - val_loss: 0.0369
# Epoch 5/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0264 - val_loss: 0.0644
# Epoch 6/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0360 - val_loss: 0.0347
# Epoch 7/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0147 - val_loss: 0.0257
# Epoch 8/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0164 - val_loss: 0.0284
# Epoch 9/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0203 - val_loss: 0.0275
# Epoch 10/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0176 - val_loss: 0.0257
# Epoch 11/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0134 - val_loss: 0.0267
# Epoch 12/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0127 - val_loss: 0.0296
# Epoch 13/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0139 - val_loss: 0.0293
# Epoch 14/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0132 - val_loss: 0.0257
# Epoch 15/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0114 - val_loss: 0.0233
# Epoch 16/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0115 - val_loss: 0.0226
# Epoch 17/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0116 - val_loss: 0.0222
# Epoch 18/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0107 - val_loss: 0.0225
# Epoch 19/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0102 - val_loss: 0.0226
# Epoch 20/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0100 - val_loss: 0.0214
# Epoch 21/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0094 - val_loss: 0.0204
# Epoch 22/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0093 - val_loss: 0.0201
# Epoch 23/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0089 - val_loss: 0.0204
# Epoch 24/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0087 - val_loss: 0.0207
# Epoch 25/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0087 - val_loss: 0.0204
# Epoch 26/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0085 - val_loss: 0.0199
# Epoch 27/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0084 - val_loss: 0.0197
# Epoch 28/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0087 - val_loss: 0.0199
# Epoch 29/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0083 - val_loss: 0.0205
# Epoch 30/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0084 - val_loss: 0.0198
# Epoch 31/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0082 - val_loss: 0.0193
# Epoch 32/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0082 - val_loss: 0.0192
# Epoch 33/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0081 - val_loss: 0.0196
# Epoch 34/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0081 - val_loss: 0.0186
# Epoch 35/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0082 - val_loss: 0.0183
# Epoch 36/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0079 - val_loss: 0.0190
# Epoch 37/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0080 - val_loss: 0.0190
# Epoch 38/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0080 - val_loss: 0.0178
# Epoch 39/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0078 - val_loss: 0.0176
# Epoch 40/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0077 - val_loss: 0.0177
# Epoch 41/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0077 - val_loss: 0.0176
# Epoch 42/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0076 - val_loss: 0.0169
# Epoch 43/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0076 - val_loss: 0.0171
# Epoch 44/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0075 - val_loss: 0.0178
# Epoch 45/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0077 - val_loss: 0.0163
# Epoch 46/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0074 - val_loss: 0.0159
# Epoch 47/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0073 - val_loss: 0.0166
# Epoch 48/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0073 - val_loss: 0.0162
# Epoch 49/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0072 - val_loss: 0.0156
# Epoch 50/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0071 - val_loss: 0.0156
# Epoch 51/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0070 - val_loss: 0.0150
# Epoch 52/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0070 - val_loss: 0.0149
# Epoch 53/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0068 - val_loss: 0.0153
# Epoch 54/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0070 - val_loss: 0.0145
# Epoch 55/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0068 - val_loss: 0.0141
# Epoch 56/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0067 - val_loss: 0.0139
# Epoch 57/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0067 - val_loss: 0.0146
# Epoch 58/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0068 - val_loss: 0.0147
# Epoch 59/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0066 - val_loss: 0.0136
# Epoch 60/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0069 - val_loss: 0.0139
# Epoch 61/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0065 - val_loss: 0.0152
# Epoch 62/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0068 - val_loss: 0.0132
# Epoch 63/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0068 - val_loss: 0.0131
# Epoch 64/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0064 - val_loss: 0.0146
# Epoch 65/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0068 - val_loss: 0.0131
# Epoch 66/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0065 - val_loss: 0.0128
# Epoch 67/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0064 - val_loss: 0.0131
# Epoch 68/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0062 - val_loss: 0.0132
# Epoch 69/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0062 - val_loss: 0.0132
# Epoch 70/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0061 - val_loss: 0.0127
# Epoch 71/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0063 - val_loss: 0.0127
# Epoch 72/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0060 - val_loss: 0.0129
# Epoch 73/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0061 - val_loss: 0.0122
# Epoch 74/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0060 - val_loss: 0.0124
# Epoch 75/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0059 - val_loss: 0.0122
# Epoch 76/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0059 - val_loss: 0.0122
# Epoch 77/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0059 - val_loss: 0.0121
# Epoch 78/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0060 - val_loss: 0.0123
# Epoch 79/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0058 - val_loss: 0.0118
# Epoch 80/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0061 - val_loss: 0.0123
# Epoch 81/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0061 - val_loss: 0.0123
# Epoch 82/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0060 - val_loss: 0.0119
# Epoch 83/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0059 - val_loss: 0.0124
# Epoch 84/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0062 - val_loss: 0.0119
# Epoch 85/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0059 - val_loss: 0.0116
# Epoch 86/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0059 - val_loss: 0.0120
# Epoch 87/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0060 - val_loss: 0.0115
# Epoch 88/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0056 - val_loss: 0.0114
# Epoch 89/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0058 - val_loss: 0.0115
# Epoch 90/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0058 - val_loss: 0.0115
# Epoch 91/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0060 - val_loss: 0.0115
# Epoch 92/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0059 - val_loss: 0.0119
# Epoch 93/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0057 - val_loss: 0.0113
# Epoch 94/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0057 - val_loss: 0.0113
# Epoch 95/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0055 - val_loss: 0.0118
# Epoch 96/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0059 - val_loss: 0.0114
# Epoch 97/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0055 - val_loss: 0.0115
# Epoch 98/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0058 - val_loss: 0.0114
# Epoch 99/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0056 - val_loss: 0.0113
# Epoch 100/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0054 - val_loss: 0.0110

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict = np.array(train_predict).reshape(-1,1)
test_predict = np.array(test_predict).reshape(-1,1)

# %%
train_predict
# Out:
# array([[0.62531835],
#        [0.5679927 ],
#        [0.49473846],
#        [0.44950438],
#        [0.44660676],
#        [0.43797052],
#        [0.44491595],
#        [0.44248727],
#        [0.45839286],
#        [0.4670062 ],
#        [0.46851832],
#        [0.47394943],
#        [0.47804573],
#        [0.5007528 ],
#        [0.525001  ],
#        [0.531965  ],
#        [0.5242196 ],
#        [0.49586126],
#        [0.46055582],
#        [0.429579  ],
#        [0.39885935],
#        [0.38826358],
#        [0.37141746],
#        [0.3496018 ],
#        [0.3254497 ],
#        [0.30068752],
#        [0.28163972],
#        [0.28017592],
#        [0.27025685],
#        [0.25841084],
#        [0.24524136],
#        [0.24006312],
#        [0.21815193],
#        [0.17702997],
#        [0.1467951 ],
#        [0.12724052],
#        [0.12239372],
#        [0.13950993],
#        [0.15454896],
#        [0.17923494],
#        [0.23305655],
#        [0.2862982 ],
#        [0.32365236],
#        [0.3250031 ],
#        [0.35560188],
#        [0.38815153],
#        [0.40200767],
#        [0.38753563],
#        [0.3766768 ],
#        [0.36637378],
#        [0.36137912],
#        [0.36611193],
#        [0.36331856],
#        [0.34652504],
#        [0.31777984],
#        [0.30262807],
#        [0.29743025],
#        [0.30541387],
#        [0.31967422],
#        [0.35122624],
#        [0.39636752],
#        [0.4341796 ],
#        [0.46007562],
#        [0.48166773],
#        [0.49172342],
#        [0.5069798 ],
#        [0.5160398 ],
#        [0.5129396 ],
#        [0.5107661 ],
#        [0.5075901 ],
#        [0.51241124],
#        [0.513295  ],
#        [0.50625056],
#        [0.5029327 ],
#        [0.4939211 ],
#        [0.4844516 ],
#        [0.48709095],
#        [0.49600002],
#        [0.5014099 ],
#        [0.49551198],
#        [0.49201003],
#        [0.48596463],
#        [0.471268  ],
#        [0.46781436],
#        [0.48745388],
#        [0.5165471 ],
#        [0.5393473 ],
#        [0.5486154 ],
#        [0.5450908 ],
#        [0.53567064],
#        [0.5386917 ],
#        [0.5473753 ],
#        [0.5595852 ],
#        [0.56464267],
#        [0.5593432 ],
#        [0.5527172 ],
#        [0.56014246],
#        [0.5763353 ],
#        [0.597148  ],
#        [0.6165665 ],
#        [0.6129699 ],
#        [0.5865594 ],
#        [0.5555672 ],
#        [0.53551775],
#        [0.5250399 ],
#        [0.50493944],
#        [0.47682407],
#        [0.44069475],
#        [0.39929372],
#        [0.36961865],
#        [0.37001678],
#        [0.40365046],
#        [0.44841152],
#        [0.4851858 ],
#        [0.51814914],
#        [0.5429095 ],
#        [0.5586349 ],
#        [0.5709578 ],
#        [0.57743484],
#        [0.57967323],
#        [0.57593507],
#        [0.5697182 ],
#        [0.5502384 ],
#        [0.51912916],
#        [0.49774665],
#        [0.48292732],
#        [0.48044354],
#        [0.48998848],
#        [0.5350469 ],
#        [0.5890982 ],
#        [0.6398661 ],
#        [0.68507075],
#        [0.7157816 ],
#        [0.7366472 ],
#        [0.7385143 ],
#        [0.7377153 ],
#        [0.72634244],
#        [0.7116367 ],
#        [0.7095123 ],
#        [0.7088614 ],
#        [0.72162956],
#        [0.74285716],
#        [0.7511635 ],
#        [0.7530725 ],
#        [0.7378836 ],
#        [0.7426901 ],
#        [0.7475177 ],
#        [0.74799514],
#        [0.73868436],
#        [0.7153572 ]], dtype=float32)

# %%
y_train
# Out:
# array([[0.40023884],
#        [0.38353239],
#        [0.54319832],
#        [0.6446303 ],
#        [0.42577571],
#        [0.44367547],
#        [0.45656336],
#        [0.56491664],
#        [0.48305495],
#        [0.45417673],
#        [0.5140812 ],
#        [0.52434385],
#        [0.59737482],
#        [0.54892601],
#        [0.51933197],
#        [0.48758961],
#        [0.44057302],
#        [0.39689749],
#        [0.43269701],
#        [0.38472571],
#        [0.45322201],
#        [0.33794772],
#        [0.28162291],
#        [0.29880685],
#        [0.28520286],
#        [0.2952269 ],
#        [0.36945119],
#        [0.23699295],
#        [0.20190954],
#        [0.25131276],
#        [0.21957041],
#        [0.15560876],
#        [0.        ],
#        [0.12124116],
#        [0.15871122],
#        [0.16038203],
#        [0.05990476],
#        [0.07708842],
#        [0.1102627 ],
#        [0.17064439],
#        [0.30954671],
#        [0.30525065],
#        [0.34630095],
#        [0.40000023],
#        [0.37852052],
#        [0.32052517],
#        [0.30906921],
#        [0.38949898],
#        [0.38257768],
#        [0.38735095],
#        [0.38019105],
#        [0.3424821 ],
#        [0.26587118],
#        [0.23579964],
#        [0.35155143],
#        [0.36300739],
#        [0.38758956],
#        [0.33556109],
#        [0.45489283],
#        [0.50381884],
#        [0.45799528],
#        [0.47494033],
#        [0.5477327 ],
#        [0.49761337],
#        [0.54940351],
#        [0.52291192],
#        [0.48400966],
#        [0.54916491],
#        [0.50811462],
#        [0.55131265],
#        [0.52863962],
#        [0.48281634],
#        [0.51861587],
#        [0.49093096],
#        [0.48042971],
#        [0.55035822],
#        [0.54510746],
#        [0.49164678],
#        [0.48066832],
#        [0.49618144],
#        [0.49522673],
#        [0.46181384],
#        [0.49427231],
#        [0.60023866],
#        [0.60525083],
#        [0.5553701 ],
#        [0.53794755],
#        [0.52911712],
#        [0.54916491],
#        [0.59546539],
#        [0.58591885],
#        [0.60763746],
#        [0.56706467],
#        [0.53341289],
#        [0.56324582],
#        [0.64510751],
#        [0.64176617],
#        [0.66133674],
#        [0.64701694],
#        [0.57088323],
#        [0.52577577],
#        [0.53054904],
#        [0.57183794],
#        [0.57613371],
#        [0.45871139],
#        [0.41670667],
#        [0.38973758],
#        [0.3498809 ],
#        [0.40835345],
#        [0.49164678],
#        [0.56420053],
#        [0.54272082],
#        [0.50238663],
#        [0.57231515],
#        [0.60119337],
#        [0.59761342],
#        [0.58114558],
#        [0.59331765],
#        [0.6033414 ],
#        [0.57828174],
#        [0.56706467],
#        [0.49952279],
#        [0.4797136 ],
#        [0.52863962],
#        [0.49379481],
#        [0.52863962],
#        [0.55751813],
#        [0.70859194],
#        [0.72028651],
#        [0.77947517],
#        [0.79761354],
#        [0.77517911],
#        [0.78854421],
#        [0.72673031],
#        [0.75942738],
#        [0.73770906],
#        [0.72911695],
#        [0.75799546],
#        [0.74367565],
#        [0.79713604],
#        [0.81980907],
#        [0.76491647],
#        [0.76252983],
#        [0.72911695],
#        [0.84272099],
#        [0.77541772],
#        [0.77016724],
#        [0.7331744 ],
#        [0.6995229 ],
#        [0.62505972]])

# %%
y_train = y_train.reshape(-1,1)
y_test = ytest.reshape(-1,1)
y_train.shape
# Out:
# (150, 1)

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
train_predict.shape , y_train.shape
# Out:
# ((150, 1), (150, 1))

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 736.1673722265181

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 723.58742765778

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(train_data, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = np.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(df1)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ELECTR~1\AppData\Local\Temp/ipykernel_10540/952362510.py in <module>
#       4 trainPredictPlot = np.empty_like(df1)
#       5 trainPredictPlot[:, :] = np.nan
# ----> 6 trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
#       7 # shift test predictions for plotting
#       8 testPredictPlot = np.empty_like(df1)
#
# ValueError: could not broadcast input array from shape (150,1) into shape (149,1)

# %%
plt.plot(train_predict, 'green', label='predicted data')
plt.plot(y_train, 'blue', label='actual data')
plt.legend()

# %%
# ARIMA 
# ADF test
from statsmodels.tsa.stattools import adfuller

# %%
# check if data is stationary
# if p-value > 0.05 we will need to differencing
result = adfuller(df.Close.dropna())
print(f"ADF statistics: {result[0]}")
print(f"p-value: {result[1]}")
# Out:
# ADF statistics: -2.4435028307047144
# p-value: 0.1298324888452843

# %%
# choose no. of d
from pmdarima.arima.utils import ndiffs
ndiffs(df.Close, test="adf")
# Out:
# 1

# %%
# partial autocorrelation function to choose p
from statsmodels.graphics.tsaplots import plot_pacf

diff =df.Close.diff().dropna()

# %%
# p=14 above signifficant line, q=17
fig , (ax1,ax2) = plt.subplots(1,2, figsize=(16,4))

ax1.plot(diff)
ax1.set_title("Difference once")
ax2.set_ylim(0,1)
plot_pacf(diff, ax=ax2)
# Out:
# C:\Users\electromera\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
df_train = df[df.Date < "2022"]
df_valid = df[df.Date >= "2022"]
df_valid
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 223  2022-01-03  680.250000  698.500000  679.000000  696.349976  696.349976
# 224  2022-01-04  701.000000  711.049988  700.049988  709.150024  709.150024
# 225  2022-01-05  711.900024  730.900024  707.750000  726.900024  726.900024
# 226  2022-01-06  719.950012  733.500000  719.000000  730.299988  730.299988
# 227  2022-01-07  734.000000  740.900024  725.250000  730.599976  730.599976
# 228  2022-01-10  733.650024  744.000000  733.200012  742.799988  742.799988
# 229  2022-01-11  742.900024  747.049988  737.299988  743.250000  743.250000
# 230  2022-01-12  749.650024  751.450012  743.150024  746.849976  746.849976
# 231  2022-01-13  749.000000  749.000000  737.049988  740.700012  740.700012
# 232  2022-01-14  734.799988  735.950012  716.049988  721.700012  721.700012
# 233  2022-01-17  719.000000  720.599976  709.500000  712.650024  712.650024
# 234  2022-01-18  717.500000  735.900024  714.250000  725.200012  725.200012
# 235  2022-01-19  725.200012  731.950012  718.700012  729.599976  729.599976
# 236  2022-01-20  731.049988  737.150024  722.150024  728.900024  728.900024
# 237  2022-01-21  722.000000  725.250000  708.049988  712.500000  712.500000
# 238  2022-01-24  715.000000  716.400024  688.200012  704.599976  704.599976
# 239  2022-01-25  714.000000  755.000000  708.599976  752.200012  752.200012
# 240  2022-01-27  744.000000  777.000000  738.099976  773.849976  773.849976
# 241  2022-01-28  778.099976  784.700012  761.500000  764.700012  764.700012
# 242  2022-01-31  775.450012  777.799988  762.349976  773.049988  773.049988
# 243  2022-02-01  778.099976  793.900024  769.099976  781.900024  781.900024
# 244  2022-02-02  790.000000  805.900024  787.349976  804.099976  804.099976
# 245  2022-02-03  802.200012  811.900024  793.049988  799.549988  799.549988
# 246  2022-02-04  796.950012  804.500000  791.150024  798.549988  798.549988
# 247  2022-02-07  802.500000  803.599976  784.099976  789.599976  789.599976
# 248  2022-02-08  794.000000  801.000000  776.150024  798.549988  798.549988
#
#        Volume
# 223   8550860
# 224   9705906
# 225  11312955
# 226   7955578
# 227  10454143
# 228   9595787
# 229   7252279
# 230   5294563
# 231   5196538
# 232  16302342
# 233  19680557
# 234  24055886
# 235   7746270
# 236   8505400
# 237  10689060
# 238   8812501
# 239  38088158
# 240  34927774
# 241  17765524
# 242  12319200
# 243  15457534
# 244  13478899
# 245  10802708
# 246  10776387
# 247  10939179
# 248  12299104

# %%
df_valid[['Open','High','Low','Close','Adj Close','Volume']] = scaler.fit_transform(df_valid[['Open','High','Low','Close','Adj Close','Volume']])
df_train[['Open','High','Low','Close','Adj Close','Volume']] = scaler.fit_transform(df_train[['Open','High','Low','Close','Adj Close','Volume']])
# Out:
# C:\Users\electromera\anaconda3\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# C:\Users\electromera\anaconda3\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
df_valid
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 223  2022-01-03  680.250000  698.500000  679.000000  696.349976  696.349976
# 224  2022-01-04  701.000000  711.049988  700.049988  709.150024  709.150024
# 225  2022-01-05  711.900024  730.900024  707.750000  726.900024  726.900024
# 226  2022-01-06  719.950012  733.500000  719.000000  730.299988  730.299988
# 227  2022-01-07  734.000000  740.900024  725.250000  730.599976  730.599976
# 228  2022-01-10  733.650024  744.000000  733.200012  742.799988  742.799988
# 229  2022-01-11  742.900024  747.049988  737.299988  743.250000  743.250000
# 230  2022-01-12  749.650024  751.450012  743.150024  746.849976  746.849976
# 231  2022-01-13  749.000000  749.000000  737.049988  740.700012  740.700012
# 232  2022-01-14  734.799988  735.950012  716.049988  721.700012  721.700012
# 233  2022-01-17  719.000000  720.599976  709.500000  712.650024  712.650024
# 234  2022-01-18  717.500000  735.900024  714.250000  725.200012  725.200012
# 235  2022-01-19  725.200012  731.950012  718.700012  729.599976  729.599976
# 236  2022-01-20  731.049988  737.150024  722.150024  728.900024  728.900024
# 237  2022-01-21  722.000000  725.250000  708.049988  712.500000  712.500000
# 238  2022-01-24  715.000000  716.400024  688.200012  704.599976  704.599976
# 239  2022-01-25  714.000000  755.000000  708.599976  752.200012  752.200012
# 240  2022-01-27  744.000000  777.000000  738.099976  773.849976  773.849976
# 241  2022-01-28  778.099976  784.700012  761.500000  764.700012  764.700012
# 242  2022-01-31  775.450012  777.799988  762.349976  773.049988  773.049988
# 243  2022-02-01  778.099976  793.900024  769.099976  781.900024  781.900024
# 244  2022-02-02  790.000000  805.900024  787.349976  804.099976  804.099976
# 245  2022-02-03  802.200012  811.900024  793.049988  799.549988  799.549988
# 246  2022-02-04  796.950012  804.500000  791.150024  798.549988  798.549988
# 247  2022-02-07  802.500000  803.599976  784.099976  789.599976  789.599976
# 248  2022-02-08  794.000000  801.000000  776.150024  798.549988  798.549988
#
#        Volume
# 223   8550860
# 224   9705906
# 225  11312955
# 226   7955578
# 227  10454143
# 228   9595787
# 229   7252279
# 230   5294563
# 231   5196538
# 232  16302342
# 233  19680557
# 234  24055886
# 235   7746270
# 236   8505400
# 237  10689060
# 238   8812501
# 239  38088158
# 240  34927774
# 241  17765524
# 242  12319200
# 243  15457534
# 244  13478899
# 245  10802708
# 246  10776387
# 247  10939179
# 248  12299104

# %%
df_valid.shape
# Out:
# (26, 7)

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_train.Close, 'green', label='Train data')
plt.plot(df_valid.Close, 'blue', label='Test data')
plt.legend()

# %%
# ARIMA MODEL
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df_train['Close'], order=(14,1,17))
result = model.fit()
# Out:
# C:\Users\electromera\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\electromera\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\electromera\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  223
# Model:               ARIMA(14, 1, 17)   Log Likelihood                 324.208
# Date:                Mon, 14 Feb 2022   AIC                           -584.416
# Time:                        18:31:53   BIC                           -475.530
# Sample:                             0   HQIC                          -540.454
#                                 - 223
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0066      4.025      0.002      0.999      -7.882       7.895
# ar.L2          0.0082      2.798      0.003      0.998      -5.476       5.492
# ar.L3         -0.1817      0.934     -0.194      0.846      -2.013       1.650
# ar.L4         -0.0245      0.684     -0.036      0.971      -1.365       1.316
# ar.L5          0.0614      0.458      0.134      0.893      -0.836       0.959
# ar.L6         -0.0161      0.475     -0.034      0.973      -0.948       0.916
# ar.L7         -0.0928      0.493     -0.188      0.851      -1.058       0.873
# ar.L8         -0.0597      0.702     -0.085      0.932      -1.436       1.317
# ar.L9         -0.1640      0.720     -0.228      0.820      -1.575       1.247
# ar.L10        -0.2105      0.897     -0.235      0.814      -1.968       1.547
# ar.L11         0.2110      1.360      0.155      0.877      -2.455       2.877
# ar.L12        -0.1886      0.713     -0.264      0.792      -1.587       1.210
# ar.L13        -0.1255      0.494     -0.254      0.799      -1.093       0.842
# ar.L14         0.1173      0.829      0.141      0.887      -1.508       1.742
# ma.L1          0.0701      4.021      0.017      0.986      -7.812       7.952
# ma.L2         -0.1246      3.036     -0.041      0.967      -6.075       5.826
# ma.L3         -0.0262      0.975     -0.027      0.979      -1.937       1.884
# ma.L4          0.0951      0.854      0.111      0.911      -1.579       1.770
# ma.L5          0.1032      0.633      0.163      0.871      -1.138       1.344
# ma.L6         -0.1322      0.740     -0.179      0.858      -1.583       1.319
# ma.L7          0.0747      0.439      0.170      0.865      -0.785       0.935
# ma.L8          0.2365      0.497      0.476      0.634      -0.737       1.210
# ma.L9          0.0289      1.190      0.024      0.981      -2.303       2.361
# ma.L10         0.0728      0.793      0.092      0.927      -1.482       1.628
# ma.L11        -0.2686      0.614     -0.437      0.662      -1.472       0.935
# ma.L12         0.0721      0.965      0.075      0.940      -1.819       1.963
# ma.L13         0.1061      0.701      0.151      0.880      -1.268       1.480
# ma.L14         0.0757      0.579      0.131      0.896      -1.059       1.210
# ma.L15         0.0658      0.783      0.084      0.933      -1.469       1.600
# ma.L16        -0.0756      0.879     -0.086      0.931      -1.798       1.647
# ma.L17         0.0838      0.446      0.188      0.851      -0.789       0.957
# sigma2         0.0031      0.000     11.583      0.000       0.003       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                28.86
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.66   Skew:                            -0.28
# Prob(H) (two-sided):                  0.08   Kurtosis:                         4.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
start = len(df_train)
end = len(df_train + df_valid)-1

# %%
pred = result.predict(start=start, end=end, dynamic=False)
pred = pd.DataFrame(pred)
pred
# Out:
#      predicted_mean
# 223      686.576440
# 224      682.955498
# 225      681.164039
# 226      675.004178
# 227      676.282816
# 228      664.273532
# 229      662.021873
# 230      663.670358
# 231      660.948817
# 232      660.645442
# 233      665.701102
# 234      665.030157
# 235      667.224393
# 236      672.748410
# 237      675.853885
# 238      680.661330
# 239      679.182073
# 240      683.176021
# 241      683.680717
# 242      678.028645
# 243      675.278091
# 244      673.953539
# 245      664.937507
# 246      664.356488
# 247      663.960816
# 248      661.332691

# %%
df1=pd.concat([df_valid.Date , df_valid.Close , pred], axis=1)
df1
# Out:
#            Date       Close  predicted_mean
# 223  2022-01-03  696.349976      686.576440
# 224  2022-01-04  709.150024      682.955498
# 225  2022-01-05  726.900024      681.164039
# 226  2022-01-06  730.299988      675.004178
# 227  2022-01-07  730.599976      676.282816
# 228  2022-01-10  742.799988      664.273532
# 229  2022-01-11  743.250000      662.021873
# 230  2022-01-12  746.849976      663.670358
# 231  2022-01-13  740.700012      660.948817
# 232  2022-01-14  721.700012      660.645442
# 233  2022-01-17  712.650024      665.701102
# 234  2022-01-18  725.200012      665.030157
# 235  2022-01-19  729.599976      667.224393
# 236  2022-01-20  728.900024      672.748410
# 237  2022-01-21  712.500000      675.853885
# 238  2022-01-24  704.599976      680.661330
# 239  2022-01-25  752.200012      679.182073
# 240  2022-01-27  773.849976      683.176021
# 241  2022-01-28  764.700012      683.680717
# 242  2022-01-31  773.049988      678.028645
# 243  2022-02-01  781.900024      675.278091
# 244  2022-02-02  804.099976      673.953539
# 245  2022-02-03  799.549988      664.937507
# 246  2022-02-04  798.549988      664.356488
# 247  2022-02-07  789.599976      663.960816
# 248  2022-02-08  798.549988      661.332691

# %%
plt.figure(figsize=(10,5), dpi=100)
plt.plot(df_valid.Close, color = 'blue', label='Actual Stock Price')
plt.plot(pred, color = 'orange', label='predicted Stock Price')
plt.legend()
plt.show()

# %%
fc = result.forecast()
fc
# Out:
# 223    0.250586
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
mse = mean_squared_error(df_valid.Close, pred)
print('MSE: '+str(mse))
mae = mean_absolute_error(df_valid.Close, pred)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(df_valid.Close, pred))
print('RMSE: '+str(rmse))
# Out:
# MSE: 6985.847584393516
# MAE: 75.74811762020218
# RMSE: 83.58138300120139
